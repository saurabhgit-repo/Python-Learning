# %%
#OOP in Python:
# To map with real world scnerios, we started using objects in code.
# That is know as Object Oriented Programming

# %%
#Procedural Prog- Sequential Prog.
#Functional Prog-   Redundancy Low Reusability Increase
#Object Oriented Prog- Using class and object

# %%
#Class and object in python:
#Class is a blueprint for creating ojects.

# %%
#Creating Class:

class Student:
    name="Saurabh Kumar"

s1=Student() #Object is the instance of class
print(s1.name)

s2=Student()
print(s2.name)
# Out:
# Saurabh Kumar
# Saurabh Kumar

# %%
class Car:
    color="blue"
    brand="BMW"

car1=Car()
print(car1.color)
print(car1.brand)
# Out:
# blue
# BMW

# %%
#Constructor: __init__ function it is invoked at object creation.
#All classes have a function called __init__() which is always executed when the object is being initiated.

class Student:
    college_name="MIT"  #Class Attributes
    #Default Constrcutor:
    def __init__(self):
        print("Adding new student in DB")

    #Parameterized Constructor
    def __init__(self,fullname,marks):
        self.name=fullname  #Object Attributes
        self.marks=marks
        print("Adding new student in DB")

s1=Student("Karan",97)  #Name and Marks values are Attributes.
print(s1.name,s1.marks,s1.college_name)

s2=Student("Akash",25)
print(s2.name,s2.marks,s2.college_name)

#Self parameter is a refernce to the current instance of the class, and is used to access variables that belongs to the class.
# Out:
# Adding new student in DB
# Karan 97 MIT
# Adding new student in DB
# Akash 25 MIT

# %%
#Class & Instance Attributes:
class Student:
    college_name="MIT"  #Class Attributes
    #Default Constrcutor:
    def __init__(self):
        print("Adding new student in DB")

    #Parameterized Constructor
    def __init__(self,fullname,marks):
        self.name=fullname  #Object Attributes
        self.marks=marks
        print("Adding new student in DB")

s1=Student("Karan",97)  #Name and Marks values are Attributes.
print(s1.name,s1.marks,s1.college_name)

s2=Student("Akash",25)
print(s2.name,s2.marks,s2.college_name)

#Class Attribute have less precedence/priority then Object Attributes

# %%
#Methods: Methods are function that belong to objects.
class Student:
    college_name="MIT" 

    def __init__(self,fullname,marks):
        self.name=fullname  #Object Attributes
        self.marks=marks

    def welcome(self):
        print("Welcome Student",s1.name)
    
    def get_marks(self):
        return self.marks

s1=Student("Saurabh",21)
s1.welcome()
print(s1.get_marks())
# Out:
# Welcome Student Saurabh
# 21

# %%
class Student:
    
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    
    def get_avg(self):
        sum=0
        for val in self.marks:
            sum=sum+val
        print("Hi",self.name,"Your avg score is",sum/3)

s1=Student("Saurabh Kumar",[98,99,97])

s1.get_avg()

s1.name="Anubhav Raj"
s1.get_avg()
# Out:
# Hi Saurabh Kumar Your avg score is 98.0
# Hi Anubhav Raj Your avg score is 98.0

# %%
#Static Methods:Method dont use the self parameter. they work at class level

class Student:
    @staticmethod #Decorator
    def college():
        print("MIT COLLEGE")

#Decorators: Decorators allow us to wrap another function in order to extend the behaviour of the wrapped function, without permanently modifying it.

# %%
#Abstraction: Hiding the implementaion of class and only showing the essential features to the user.

#Encapsulation: Wrapping data and function into a single unit(object)

# %%
#Abstraction:

class Car:
    def __init__(self):
        self.acc=False
        self.brk=False
        self.clutch=True

    def start(self):
        self.clutch=True
        self.acc=True
        print("Car Started")

car1=Car()
car1.start()
# Out:
# Car Started

# %%
#Encapsulation:
#Wrapping data and function into a single unit(object)

# %%
class Account:
    def __init__(self,bal,acc):
        self.balance=bal
        self.account_no=acc
    
    #Debit Method:
    def debit(self,amount):
        self.balance=- amount
        print("Rs.",amount,"was debited")
    
    #Credit Method:
    def credit(self,amount):
        self.balance=+ amount
        print("Rs.",amount,"was credited")

    #Final
    def get_balance(self):
        return self.balance

acc1=Account(10000,12345)
acc1.debit(1000)
acc1.credit(500)
acc1.credit(40000)

acc1.get_balance()
# Out:
# Rs. 1000 was debited
# Rs. 500 was credited
# Rs. 40000 was credited
# 40000

# %%
#Del keyword

class Student:
    def __init__(self,name):
        self.name=name
    
s1=Student("Saurabh")

del s1.name
print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 10
#       7 s1=Student("Saurabh")
#       9 del s1.name
# ---> 10 print(s1.name)
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
#Private attributes & methods:

class Account:
    def __init__(self,acc_no,acc_pass):
        self.acc_no=acc_no
        self.__acc_pass=acc_pass  #Double underscore
    
    def reset_pass(self):
        print(self.__acc_pass)

acc1=Account("12345","ABCDE")

print(acc1.acc_no)
print(acc1.reset_pass())
# Out:
# 12345
# ABCDE
# None

# %%
#Private attributes & methods:
class Person:
    __name="Saurabh"

    def __hello(self):
        print("Hello person !")
    
    def welcome(self):
        self.__hello()

p1=Person()
print(p1.welcome())
# Out:
# Hello person !
# None

# %%
#Inheritance:
#When one class(child/derived) derives the properties & methods of another class(parent/base).

class Car:
    color="Black"
    @staticmethod
    def start():
        print("Car Started")
    
    @staticmethod
    def stop():
        print("Car Stopeed")

class ToyotaCar(Car):
    def __init__(self,name):
        self.name=name

car1= ToyotaCar("Fortuner")
car2= ToyotaCar("Prius")

print(car1.name)
print(car1.color)
print(car1.start())
# Out:
# Fortuner
# Black
# Car Started
# None

# %%
#Single level inheritance:
class Car:
    color="Black"
    @staticmethod
    def start():
        print("Car Started")
    
    @staticmethod
    def stop():
        print("Car Stopeed")

class ToyotaCar(Car):
    def __init__(self,name):
        self.name=name

car1= ToyotaCar("Fortuner")
car2= ToyotaCar("Prius")

print(car1.name)
print(car1.color)
print(car1.start())

# %%
#Multi-level Inheritance-DADA,PAPA,HUM
class Car:
    color="Black"
    @staticmethod
    def start():
        print("Car Started")
    
    @staticmethod
    def stop():
        print("Car Stopeed")

class ToyotaCar(Car):
    def __init__(self,brand):
        self.brand=brand

class Fortuner(ToyotaCar):
    def __init__(self,type):
        self.type=type

car1=Fortuner("Diesel")
car1.start()
# Out:
# Car Started

# %%
#Multiple Inheritance:Child class-Inherit properties from Class1 and Class2
class A:
    varA= "Welcome to class A"
class B:
    varB= "Welcome to class B"

class C(A,B):
    varC= "Welcome to class C"

c1=C()
print(c1.varA)
print(c1.varB)
print(c1.varC)
# Out:
# Welcome to class A
# Welcome to class B
# Welcome to class C

# %%
#Super Method:super() method is used to access method of the parent class.
class Car:
    def __init__(self,type):
        self.type=type

    @staticmethod
    def start():
        print("Car Started")
    
    @staticmethod
    def stop():
        print("Car Stopeed")

class ToyotaCar(Car):
    def __init__(self,name,type):
        self.name=name
        super().__init__(type)


car1=ToyotaCar("Prius","Electric")
print(car1.type)
# Out:
# Electric

# %%
#Polymorphism: Poly means many morpho means forms

#Operator Overloading: When the same operatr is allowed to have different meaning according to the context.

class Complex:
    def __init__(self,real,img):
        self.real=real
        self.img=img

    def showNumber(self):
        print(self.real,"i+",self.img,"j")

    def __add__(self,num2):
        newReal=self.real + num2.real
        newImg=self.img + num2.img
        return Complex(newReal,newImg)
num1=Complex(1,3)
num1.showNumber()

num2=Complex(4,5)
num2.showNumber()

num3=num1+num2
num3.showNumber()
# Out:
# 1 i+ 3 j
# 4 i+ 5 j
# 5 i+ 8 j
